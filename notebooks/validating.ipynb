# %%
import pandas as pd

df = pd.read_csv("/Users/hassan_aoun/Documents/GitHub/wholesale-distribution-analytics-platform/data/raw/order_lines.csv")


display(df.head())
print("shape:", df.shape)
print("columns:", list(df.columns))
df.info()
# Out:
#    OrderLineID      OrderID    ProductID  Quantity  UnitPrice  UnitCost  \
# 0  OL-00000001  ORD-0247388  PROD-037582         2     847.34     84.42
# 1  OL-00000002  ORD-0186672  PROD-016386        10     913.80     16.67
# 2  OL-00000003  ORD-0021101  PROD-044085        21      59.22    444.89
# 3  OL-00000004  ORD-0349136  PROD-046949        18     623.87    308.00
# 4  OL-00000005  ORD-0370874  PROD-004694         6     147.16    160.38
#
#    DiscountPct
# 0            0
# 1           15
# 2           15
# 3            0
# 4            0
# shape: (2000000, 7)
# columns: ['OrderLineID', 'OrderID', 'ProductID', 'Quantity', 'UnitPrice', 'UnitCost', 'DiscountPct']
# <class 'pandas.DataFrame'>
# RangeIndex: 2000000 entries, 0 to 1999999
# Data columns (total 7 columns):
#  #   Column       Dtype
# ---  ------       -----
#  0   OrderLineID  str
#  1   OrderID      str
#  2   ProductID    str
#  3   Quantity     int64
#  4   UnitPrice    float64
#  5   UnitCost     float64
# ...

# %%
import pandas as pd

df = pd.read_csv(
    "/Users/hassan_aoun/Documents/GitHub/wholesale-distribution-analytics-platform/data/raw/customers.csv"
)

print(df.shape)

print(
    df["CustomerID"].nunique()
)
# Out:
# (100000, 8)
# 100000

# %%
import pandas as pd

print("Customers:", len(pd.read_csv("/Users/hassan_aoun/Documents/GitHub/wholesale-distribution-analytics-platform/data/raw/customers.csv")))
print("Orders:", len(pd.read_csv("/Users/hassan_aoun/Documents/GitHub/wholesale-distribution-analytics-platform/data/raw/orders.csv")))
print("Order Lines:", len(pd.read_csv("/Users/hassan_aoun/Documents/GitHub/wholesale-distribution-analytics-platform/data/raw/order_lines.csv")))
# Out:
# Customers: 100000
# Orders: 500000
# Order Lines: 2000000
